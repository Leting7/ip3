# %%
## Import numpy and panda libraries
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('cells_geo.csv', delimiter = ';')
df
# Out:
#       Unnamed: 0       VILLES  ...     CELL_ID   SITE_CODE
# 0              0       ADJAME  ...  fbb2e75af3  0bb492ef17
# 1              1       ADJAME  ...  1502501d78  0bb492ef17
# 2              2       ADJAME  ...  0c2e182a0c  0bb492ef17
# 3              3      ASSINIE  ...  69bdfc69fd  8a1e6ce31f
# 4              4      ASSINIE  ...  7a1029d2ab  8a1e6ce31f
# 5              5      ASSINIE  ...  0b4f56438f  8a1e6ce31f
# 6              6     KRIKOREA  ...  041d2504f5  260dbfedc5
# 7              7        ABOBO  ...  a70c1d263b  56306cc7ca
# 8              8        ABOBO  ...  e2d04ea883  56306cc7ca
# 9              9        ABOBO  ...  ee224cd27e  56306cc7ca
# 10            10        ABOBO  ...  107d0d752c  56306cc7ca
# 11            11        ABOBO  ...  3f766cedc0  c1ccd3443b
# 12            12        ABOBO  ...  b0578cdb7f  c1ccd3443b
# 13            13        ABOBO  ...  18a4221316  c1ccd3443b
# 14            14        ABOBO  ...  1b2bccad1f  c1ccd3443b
# ...

# %%
df2 = pd.read_csv('MoringaSchool_CB_CDR_20120507.csv', delimiter = ',')
df2
# Out:
#        PRODUTC  VALUE               DATETIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0        Voice      0  2012-05-06 23:04:37.0  ...     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1          sms      0  2012-05-06 23:05:25.0  ...     19e2e  /+cKZKIp41  /+cKZKIp41
# 2          sms     25  2012-05-06 23:05:41.0  ...     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3        Voice     56  2012-05-06 23:05:42.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4        Voice     14  2012-05-06 23:06:29.0  ...     19e2e  051KhYDCpv  051KhYDCpv
# 5         data      0  2012-05-06 23:07:26.0  ...     OTHER  /lrUXVGVcN  /lrUXVGVcN
# 6        Voice      0  2012-05-06 23:08:02.0  ...     19e2e  +38u2u/rfx  +38u2u/rfx
# 7        Voice      0  2012-05-06 23:08:03.0  ...     19e2e  09UjmmY1Ds  09UjmmY1Ds
# 8        Voice      0  2012-05-06 23:08:05.0  ...     19e2e  0DeimCpZOc  0DeimCpZOc
# 9          sms      0  2012-05-06 23:08:43.0  ...     19e2e  01MDiY5F89  01MDiY5F89
# ...

# %%
df1 = pd.read_csv('MoringaSchool_CB_CDR_20120508.csv', delimiter = ',')
df1
# Out:
#       PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0         sms      0  2012-05-07 23:02:06.0  ...     19e2e  +854AcBQT2  +854AcBQT2
# 1       Voice      0  2012-05-07 23:03:44.0  ...     19e2e  +854AcBQT2  +854AcBQT2
# 2         sms      0  2012-05-07 23:04:06.0  ...     19e2e  +laSrk7g6q  +laSrk7g6q
# 3       Voice     37  2012-05-07 23:04:48.0  ...     19e2e  /xvRrCVKoQ  /xvRrCVKoQ
# 4         sms     25  2012-05-07 23:04:58.0  ...     19e2e  +bO+qkSonO  +bO+qkSonO
# 5         sms      0  2012-05-07 23:05:41.0  ...     19e2e  /MMplBlWjh  /MMplBlWjh
# 6       Voice     41  2012-05-07 23:06:14.0  ...     19e2e  +laSrk7g6q  +laSrk7g6q
# 7       Voice     11  2012-05-07 23:06:28.0  ...     19e2e  +gySf02tKW  +gySf02tKW
# 8         sms      0  2012-05-07 23:06:35.0  ...     OTHER  /0FxP3az1x  /0FxP3az1x
# 9         sms      0  2012-05-07 23:06:50.0  ...     19e2e  0ecjmwPX21  0ecjmwPX21
# ...

# %%
df3 = pd.read_csv('MoringaSchool_CB_CDR_20120509.csv', delimiter = ',')
df3
# Out:
#         PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B      CELLID     SIET_ID
# 0         Voice     61  2012-05-08 23:01:28.0  ...     19e2e  +38u2u/rfx  +38u2u/rfx
# 1           sms      0  2012-05-08 23:01:31.0  ...     19e2e  +Fs4mTvdKx  +Fs4mTvdKx
# 2         Voice     10  2012-05-08 23:02:59.0  ...     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 3           sms      0  2012-05-08 23:03:04.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4         Voice     22  2012-05-08 23:03:16.0  ...     19e2e  /eeMklgyJA  /eeMklgyJA
# 5         Voice     10  2012-05-08 23:03:59.0  ...     19e2e  +e+xcimwre  +e+xcimwre
# 6           sms      0  2012-05-08 23:06:06.0  ...     19e2e  +R5ccmtyJf  +R5ccmtyJf
# 7         Voice     10  2012-05-08 23:06:55.0  ...     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 8           sms     25  2012-05-08 23:07:09.0  ...     19e2e  13O1+JEun3  13O1+JEun3
# 9           sms      0  2012-05-08 23:07:38.0  ...     19e2e  /eeMklgyJA  /eeMklgyJA
# ...

# %%
df4 = pd.read_excel('CDR_description.xlsx')
df4
# Out:
#        Column name                                        Description   Format
# 0          PRODUCT                                       Voice or SMS   String
# 1            VALUE                                      Billing price  Integer
# 2        DATE_TIME               Time in format yyyy-MM-dd hh:mm:ss.0   String
# 3     CELL_ON_SITE  Which cell in the site was used (not needed here)  Integer
# 4  DW_A_NUMBER_INT  Anonymized phone number of the person for whic...   String
# 5  DW_B_NUMBER_INT        Anonymized phone number of the counterparty   String
# 6        COUNTRY_A                  Country of party A (useless here)   String
# 7        COUNTRY_B                  Country of party B (useless here)   String
# 8          CELL_ID                                     ID of the cell   String
# 9          SITE_ID                                     ID of the SITE   String

# %%
df5 = pd.read_excel('cells_geo_description.xlsx')
df5
# Out:
#      Column name                                        Description  Format
# 0         VILLES                                               City  String
# 1         STATUS                                  In Service or not  String
# 2   LOCALISATION                                  in ABIDJAN or not  String
# 3     DECOUPZONE                                  Geographical Zone  String
# 4       ZONENAME                                       Name of Zone  String
# 5      LONGITUDE                                          Longitude   Float
# 6       LATITUDE                                           Latitude   Float
# 7         REGION                                             Region  String
# 8           AREA                                               Area  String
# 9        CELL_ID                                     ID of the cell  String
# 10     SITE_CODE  Site (there are several cells per site, severa...  String

# %%
df2.rename(columns={'PRODUTC': 'PRODUCT'}, inplace=True)
df2.head()
# Out:
#   PRODUCT  VALUE               DATETIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0   Voice      0  2012-05-06 23:04:37.0  ...     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1     sms      0  2012-05-06 23:05:25.0  ...     19e2e  /+cKZKIp41  /+cKZKIp41
# 2     sms     25  2012-05-06 23:05:41.0  ...     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3   Voice     56  2012-05-06 23:05:42.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4   Voice     14  2012-05-06 23:06:29.0  ...     19e2e  051KhYDCpv  051KhYDCpv
#
# [5 rows x 10 columns]

# %%
df3.rename(columns={'SIET_ID': 'SITE_ID'}, inplace=True)
df3.head()
# Out:
#   PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B      CELLID     SITE_ID
# 0   Voice     61  2012-05-08 23:01:28.0  ...     19e2e  +38u2u/rfx  +38u2u/rfx
# 1     sms      0  2012-05-08 23:01:31.0  ...     19e2e  +Fs4mTvdKx  +Fs4mTvdKx
# 2   Voice     10  2012-05-08 23:02:59.0  ...     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 3     sms      0  2012-05-08 23:03:04.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4   Voice     22  2012-05-08 23:03:16.0  ...     19e2e  /eeMklgyJA  /eeMklgyJA
#
# [5 rows x 10 columns]

# %%
df1.rename(columns={'DW_A_NUMBER': 'DW_A_NUMBER_INT', 'DW_B_NUMBER': 'DW_B_NUMBER_INT'}, inplace=True)
df1.head()
# Out:
#   PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0     sms      0  2012-05-07 23:02:06.0  ...     19e2e  +854AcBQT2  +854AcBQT2
# 1   Voice      0  2012-05-07 23:03:44.0  ...     19e2e  +854AcBQT2  +854AcBQT2
# 2     sms      0  2012-05-07 23:04:06.0  ...     19e2e  +laSrk7g6q  +laSrk7g6q
# 3   Voice     37  2012-05-07 23:04:48.0  ...     19e2e  /xvRrCVKoQ  /xvRrCVKoQ
# 4     sms     25  2012-05-07 23:04:58.0  ...     19e2e  +bO+qkSonO  +bO+qkSonO
#
# [5 rows x 10 columns]

# %%
df3.rename(columns={'CELLID': 'CELL_ID'}, inplace=True)
df3.head(1)
# Out:
#   PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0   Voice     61  2012-05-08 23:01:28.0  ...     19e2e  +38u2u/rfx  +38u2u/rfx
#
# [1 rows x 10 columns]

# %%
df2.rename(columns={'DATETIME': 'DATE_TIME'}, inplace=True)
df2.head(1)
# Out:
#   PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0   Voice      0  2012-05-06 23:04:37.0  ...     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
#
# [1 rows x 10 columns]

# %%
# counterchecking the columns rename  codes
df2.head(0)
# Out:
# Empty DataFrame
# Columns: [PRODUCT, VALUE, DATE_TIME, CELL_ON_SITE, DW_A_NUMBER_INT, DW_B_NUMBER_INT, COUNTRY_A, COUNTRY_B, CELL_ID, SITE_ID]
# Index: []

# %%
df3.head(0)
# Out:
# Empty DataFrame
# Columns: [PRODUCT, VALUE, DATE_TIME, CELL_ON_SITE, DW_A_NUMBER_INT, DW_B_NUMBER_INT, COUNTRY_A, COUNTRY_B, CELL_ID, SITE_ID]
# Index: []

# %%
df1.head(0)
# Out:
# Empty DataFrame
# Columns: [PRODUCT, VALUE, DATE_TIME, CELL_ON_SITE, DW_A_NUMBER_INT, DW_B_NUMBER_INT, COUNTRY_A, COUNTRY_B, CELL_ID, SITE_ID]
# Index: []

# %%
#getting info abt the types and attributes of a given datsets for data understanding
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21732 entries, 0 to 21731
# Data columns (total 10 columns):
# PRODUCT            21732 non-null object
# VALUE              21732 non-null int64
# DATE_TIME          21732 non-null object
# CELL_ON_SITE       21732 non-null object
# DW_A_NUMBER_INT    21732 non-null object
# DW_B_NUMBER_INT    21732 non-null object
# COUNTRY_A          21732 non-null object
# COUNTRY_B          21732 non-null object
# CELL_ID            21732 non-null object
# SITE_ID            19162 non-null object
# dtypes: int64(1), object(9)
# memory usage: 1.7+ MB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273919 entries, 0 to 273918
# Data columns (total 10 columns):
# PRODUCT            273919 non-null object
# VALUE              273919 non-null int64
# DATE_TIME          273919 non-null object
# CELL_ON_SITE       273919 non-null object
# DW_A_NUMBER_INT    273919 non-null object
# DW_B_NUMBER_INT    273918 non-null object
# COUNTRY_A          273918 non-null object
# COUNTRY_B          273918 non-null object
# CELL_ID            273918 non-null object
# SITE_ID            217776 non-null object
# dtypes: int64(1), object(9)
# memory usage: 20.9+ MB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1027228 entries, 0 to 1027227
# Data columns (total 10 columns):
# PRODUCT            1027228 non-null object
# VALUE              1027228 non-null int64
# DATE_TIME          1027228 non-null object
# CELL_ON_SITE       1027228 non-null object
# DW_A_NUMBER_INT    1027228 non-null object
# DW_B_NUMBER_INT    1027227 non-null object
# COUNTRY_A          1027227 non-null object
# COUNTRY_B          1027227 non-null object
# CELL_ID            1027227 non-null object
# SITE_ID            938112 non-null object
# dtypes: int64(1), object(9)
# memory usage: 78.4+ MB

# %%
#creation of dataframes for the databases
#
df2_d= pd.DataFrame(df2)
df2_d.head()
# Out:
#   PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0   Voice      0  2012-05-06 23:04:37.0  ...     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1     sms      0  2012-05-06 23:05:25.0  ...     19e2e  /+cKZKIp41  /+cKZKIp41
# 2     sms     25  2012-05-06 23:05:41.0  ...     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3   Voice     56  2012-05-06 23:05:42.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4   Voice     14  2012-05-06 23:06:29.0  ...     19e2e  051KhYDCpv  051KhYDCpv
#
# [5 rows x 10 columns]

# %%
df1_d = pd.DataFrame(df2)
df1_d.head()
# Out:
#   PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0   Voice      0  2012-05-06 23:04:37.0  ...     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1     sms      0  2012-05-06 23:05:25.0  ...     19e2e  /+cKZKIp41  /+cKZKIp41
# 2     sms     25  2012-05-06 23:05:41.0  ...     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3   Voice     56  2012-05-06 23:05:42.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4   Voice     14  2012-05-06 23:06:29.0  ...     19e2e  051KhYDCpv  051KhYDCpv
#
# [5 rows x 10 columns]

# %%
df3_d = pd.DataFrame(df3)
df3_d.head()
# Out:
#   PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0   Voice     61  2012-05-08 23:01:28.0  ...     19e2e  +38u2u/rfx  +38u2u/rfx
# 1     sms      0  2012-05-08 23:01:31.0  ...     19e2e  +Fs4mTvdKx  +Fs4mTvdKx
# 2   Voice     10  2012-05-08 23:02:59.0  ...     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 3     sms      0  2012-05-08 23:03:04.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4   Voice     22  2012-05-08 23:03:16.0  ...     19e2e  /eeMklgyJA  /eeMklgyJA
#
# [5 rows x 10 columns]

# %%
#Concatination of all the dataframes 
con = pd.concat([df1_d, df2_d, df3_d])
con = con.reset_index(drop=True)
con.head()
# Out:
#   PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0   Voice      0  2012-05-06 23:04:37.0  ...     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1     sms      0  2012-05-06 23:05:25.0  ...     19e2e  /+cKZKIp41  /+cKZKIp41
# 2     sms     25  2012-05-06 23:05:41.0  ...     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3   Voice     56  2012-05-06 23:05:42.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4   Voice     14  2012-05-06 23:06:29.0  ...     19e2e  051KhYDCpv  051KhYDCpv
#
# [5 rows x 10 columns]

# %%
con[['DATE', 'TIME']] = con.DATE_TIME.str.split(expand=True)
con.head()
# Out:
#   PRODUCT  VALUE              DATE_TIME  ...     SITE_ID        DATE        TIME
# 0   Voice      0  2012-05-06 23:04:37.0  ...  /TJNe+Mmtu  2012-05-06  23:04:37.0
# 1     sms      0  2012-05-06 23:05:25.0  ...  /+cKZKIp41  2012-05-06  23:05:25.0
# 2     sms     25  2012-05-06 23:05:41.0  ...  /u0FSD+ahi  2012-05-06  23:05:41.0
# 3   Voice     56  2012-05-06 23:05:42.0  ...  +cNeJzsTp3  2012-05-06  23:05:42.0
# 4   Voice     14  2012-05-06 23:06:29.0  ...  051KhYDCpv  2012-05-06  23:06:29.0
#
# [5 rows x 12 columns]

# %%
# due to their being a a separate date and time column the date_time is no longer necessary
del con['DATE_TIME']
con.head()
# Out:
#   PRODUCT  VALUE CELL_ON_SITE  ...     SITE_ID        DATE        TIME
# 0   Voice      0            1  ...  /TJNe+Mmtu  2012-05-06  23:04:37.0
# 1     sms      0            0  ...  /+cKZKIp41  2012-05-06  23:05:25.0
# 2     sms     25            0  ...  /u0FSD+ahi  2012-05-06  23:05:41.0
# 3   Voice     56            1  ...  +cNeJzsTp3  2012-05-06  23:05:42.0
# 4   Voice     14            1  ...  051KhYDCpv  2012-05-06  23:06:29.0
#
# [5 rows x 11 columns]

# %%
#grouping the  products columns to find most used product
con.VALUE.groupby(con["PRODUCT"]).sum()
# Out:
# PRODUCT
# Voice    34346877
# data       695214
# sms       1743201
# Name: VALUE, dtype: int64

# %%
##
con.columns = map(str.lower, con.columns)
con.head()
# Out:
#   product  value cell_on_site  ...     site_id        date        time
# 0   Voice      0            1  ...  /TJNe+Mmtu  2012-05-06  23:04:37.0
# 1     sms      0            0  ...  /+cKZKIp41  2012-05-06  23:05:25.0
# 2     sms     25            0  ...  /u0FSD+ahi  2012-05-06  23:05:41.0
# 3   Voice     56            1  ...  +cNeJzsTp3  2012-05-06  23:05:42.0
# 4   Voice     14            1  ...  051KhYDCpv  2012-05-06  23:06:29.0
#
# [5 rows x 11 columns]

# %%
##
df.isnull().values.any()
# Out:
# True

# %%
#itirating through the columns
df.isnull().sum()
# Out:
# Unnamed: 0       0
# VILLES           0
# STATUS          67
# LOCALISATION     0
# DECOUPZONE       0
# ZONENAME         6
# LONGITUDE        0
# LATITUDE         0
# REGION           0
# AREA            23
# CELL_ID          0
# SITE_CODE        0
# dtype: int64

# %%
# !git
# Out:
# usage: git [--version] [--help] [-C <path>] [-c <name>=<value>]
#            [--exec-path[=<path>]] [--html-path] [--man-path] [--info-path]
#            [-p | --paginate | --no-pager] [--no-replace-objects] [--bare]
#            [--git-dir=<path>] [--work-tree=<path>] [--namespace=<name>]
#            <command> [<args>]
#
# These are common Git commands used in various situations:
#
# start a working area (see also: git help tutorial)
#    clone      Clone a repository into a new directory
#    init       Create an empty Git repository or reinitialize an existing one
#
# work on the current change (see also: git help everyday)
#    add        Add file contents to the index
#    mv         Move or rename a file, a directory, or a symlink
#    reset      Reset current HEAD to the specified state
#    rm         Remove files from the working tree and from the index
#
# examine the history and state (see also: git help revisions)
# ...
